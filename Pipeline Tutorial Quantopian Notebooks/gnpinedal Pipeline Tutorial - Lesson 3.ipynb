# %% [markdown]
# ##Factors
# A factor is a function from an asset and a moment in time to a number.
# ```
# F(asset, timestamp) -> float
# ```
# In Pipeline, [Factors](https://www.quantopian.com/help#quantopian_pipeline_factors_Factor) are the most commonly-used term, representing the result of any computation producing a numerical result. Factors require a column of data and a window length as input.
#
# The simplest factors in Pipeline are [built-in Factors](https://www.quantopian.com/help#built-in-factors). Built-in Factors are pre-built to perform common computations. As a first example, let's make a factor to compute the average close price over the last 20 days. We can use the `SimpleMovingAverage` built-in factor which computes the average value of the input data (close price) over the specified window length (10 days). To do this, we need to import our built-in `SimpleMovingAverage` factor and the [USEquityPricing dataset](https://www.quantopian.com/help#importing-datasets).

# %%
from quantopian.pipeline import Pipeline
from quantopian.research import run_pipeline

# New from the last lesson, import the USEquityPricing dataset.
from quantopian.pipeline.data.builtin import USEquityPricing

# New from the last lesson, import the built-in SimpleMovingAverage factor.
from quantopian.pipeline.factors import SimpleMovingAverage

# %% [markdown]
# ###Creating a Factor
# Let's go back to our `make_pipeline` function from the previous lesson and instantiate a `SimpleMovingAverage` factor. To create a `SimpleMovingAverage` factor, we can call the `SimpleMovingAverage` constructor with two arguments: inputs, which must be a list of `BoundColumn` objects, and window_length, which must be an integer indicating how many days worth of data our moving average calculation should receive. (We'll discuss `BoundColumn` in more depth later; for now we just need to know that a `BoundColumn` is an object indicating what kind of data should be passed to our Factor.).
#
# The following line creates a `Factor` for computing the 20-day mean close price of securities.

# %%
mean_close_20 = SimpleMovingAverage(inputs=[USEquityPricing.close], window_length=20)

# %% [markdown]
# It's important to note that creating the factor does not actually perform a computation. Creating a factor is like defining the function. To perform a computation, we need to add the factor to our pipeline and run it.

# %% [markdown]
# ###Adding a Factor to a Pipeline
# Let's update our original empty pipeline to make it compute our new moving average factor. To start, let's move our factor instantatiation into `make_pipeline`. Next, we can tell our pipeline to compute our factor by passing it a `columns` argument, which should be a dictionary mapping column names to factors, filters, or classifiers. Our updated `make_pipeline` function should look something like this:

# %%
def make_pipeline():
    
    mean_close_20 = SimpleMovingAverage(inputs=[USEquityPricing.close], window_length=20)
    
    return Pipeline(
        columns={
            '20_day_mean_close': mean_close_20
        }
    )

# %% [markdown]
# To see what this looks like, let's make our pipeline, run it, and display the result.

# %%
result = run_pipeline(make_pipeline(), '2017-12-27', '2017-12-27')
result
# Out:
# <b>Pipeline Execution Time:</b> 16.24 Seconds
#                                                    20_day_mean_close
# 2017-12-27 00:00:00+00:00 Equity(2 [HWM])                  25.110000
#                           Equity(21 [AAME])                 3.547750
#                           Equity(24 [AAPL])               172.058500
#                           Equity(25 [HWM_PR])              89.995520
#                           Equity(31 [ABAX])                48.442260
#                           Equity(41 [ARCB])                36.781250
#                           Equity(52 [ABM])                 41.227950
#                           Equity(53 [ABMD])               191.554000
#                           Equity(62 [ABT])                 55.724750
#                           Equity(64 [GOLD])                14.036000
#                           Equity(66 [AB])                  25.305000
#                           Equity(67 [ADSK])               107.909250
#                           Equity(70 [VBF])                 19.576697
#                           Equity(76 [TAP])                 80.002500
#                           Equity(84 [ACET])                10.534203
#                           Equity(100 [IEP])                52.562750
#                           Equity(106 [ACU])                23.540684
#                           Equity(110 [RAMP])               27.353000
#                           Equity(112 [ACY])                14.902368
#                           Equity(114 [ADBE])              175.358750
#                           Equity(117 [AEY])                 1.461600
#                           Equity(122 [ADI])                86.482124
#                           Equity(128 [ADM])                40.516500
#                           Equity(149 [ADX])                14.918450
#                           Equity(153 [AE])                 46.362147
#                           Equity(154 [AEM])                43.435799
#                           Equity(157 [AEG])                 6.200500
#                           Equity(161 [AEP])                76.017550
#                           Equity(166 [AES])                10.703250
#                           Equity(168 [AET])               179.753000
# ...                                                              ...
#                           Equity(51570 [DGBP])                   NaN
#                           Equity(51571 [UAUD])             26.545000
#                           Equity(51573 [UGBP])                   NaN
#                           Equity(51574 [UCHF])             25.320000
#                           Equity(51575 [UEUR])                   NaN
#                           Equity(51576 [CASA])             15.077143
#                           Equity(51577 [FTNW])             10.839250
#                           Equity(51578 [LFIN])             47.376125
#                           Equity(51579 [USAI])             25.497800
#                           Equity(51580 [NMRK])             15.210000
#                           Equity(51581 [ICLK])              9.500000
#                           Equity(51582 [HMOP])             40.104000
#                           Equity(51583 [RILY_G])           25.120800
#                           Equity(51584 [VNO_PRM])          25.165000
#                           Equity(51585 [COWN_Z])           25.332500
#                           Equity(51587 [CSWC_L])           25.649667
#                           Equity(51590 [SRG_PRA])          24.285000
#                           Equity(51591 [DOGZ])              5.817500
#                           Equity(51593 [LX])               13.190000
#                           Equity(51594 [JPBI])             25.193000
#                           Equity(51595 [KIM_PRM])          24.860333
#                           Equity(51596 [WBS_PRF])          25.046667
#                           Equity(51597 [ESTR_W])            0.800000
#                           Equity(51598 [ESTR])              9.250000
#                           Equity(51599 [DLPN_W])            2.141000
#                           Equity(51600 [WCHN])             30.954500
#                           Equity(51601 [WBAL])             25.000000
#                           Equity(51602 [LDRS])             25.290000
#                           Equity(51603 [STNL_W])                 NaN
#                           Equity(51604 [STNL])                   NaN
#
# [8520 rows x 1 columns]

# %% [markdown]
# Now we have a column in our pipeline output with the 20-day average close price for all 8000+ securities (display truncated). Note that each row corresponds to the result of our computation for a given security on a given date stored. The `DataFrame` has a [MultiIndex](http://pandas.pydata.org/pandas-docs/version/0.16.2/advanced.html) where the first level is a datetime representing the date of the computation and the second level is an [Equity](http://localhost:3000/help#api-sidinfo) object corresponding to the security. For example, the first row (`2017-12-27 00:00:00+00:00`, `Equity(2 [HWM])`) will contain the result of our `mean_close_20` factor for HWM on December 27th, 2017.
#
# If we run our pipeline over more than one day, the output looks like this.

# %%
result = run_pipeline(make_pipeline(), '2017-12-26', '2017-12-28')
result
# Out:
# <b>Pipeline Execution Time:</b> 0.41 Seconds
#                                                    20_day_mean_close
# 2017-12-26 00:00:00+00:00 Equity(2 [HWM])                  24.937500
#                           Equity(21 [AAME])                 3.547750
#                           Equity(24 [AAPL])               172.234000
#                           Equity(25 [HWM_PR])              89.999249
#                           Equity(31 [ABAX])                48.445030
#                           Equity(41 [ARCB])                36.673750
#                           Equity(52 [ABM])                 41.371450
#                           Equity(53 [ABMD])               191.992500
#                           Equity(62 [ABT])                 55.683750
#                           Equity(64 [GOLD])                14.017992
#                           Equity(66 [AB])                  25.292500
#                           Equity(67 [ADSK])               109.231250
#                           Equity(70 [VBF])                 19.581891
#                           Equity(76 [TAP])                 79.858796
#                           Equity(84 [ACET])                10.543897
#                           Equity(100 [IEP])                52.555200
#                           Equity(106 [ACU])                23.536737
#                           Equity(110 [RAMP])               27.321500
#                           Equity(112 [ACY])                14.895632
#                           Equity(114 [ADBE])              175.885750
#                           Equity(117 [AEY])                 1.463100
#                           Equity(122 [ADI])                86.398662
#                           Equity(128 [ADM])                40.457500
#                           Equity(149 [ADX])                14.902200
#                           Equity(153 [AE])                 46.429394
#                           Equity(154 [AEM])                43.398570
#                           Equity(157 [AEG])                 6.192000
#                           Equity(161 [AEP])                76.205050
#                           Equity(166 [AES])                10.707750
#                           Equity(168 [AET])               179.537500
# ...                                                              ...
# 2017-12-28 00:00:00+00:00 Equity(51576 [CASA])             15.173750
#                           Equity(51577 [FTNW])             10.773778
#                           Equity(51578 [LFIN])             48.614333
#                           Equity(51579 [USAI])             25.497800
#                           Equity(51580 [NMRK])             15.247500
#                           Equity(51581 [ICLK])              9.526667
#                           Equity(51582 [HMOP])             40.121667
#                           Equity(51583 [RILY_G])           25.159000
#                           Equity(51584 [VNO_PRM])          25.191429
#                           Equity(51585 [COWN_Z])           25.368600
#                           Equity(51587 [CSWC_L])           25.749750
#                           Equity(51590 [SRG_PRA])          24.304000
#                           Equity(51591 [DOGZ])              5.808000
#                           Equity(51593 [LX])               13.320000
#                           Equity(51594 [JPBI])             25.181667
#                           Equity(51595 [KIM_PRM])          24.867750
#                           Equity(51596 [WBS_PRF])          25.065000
#                           Equity(51597 [ESTR_W])            0.794000
#                           Equity(51598 [ESTR])              9.205000
#                           Equity(51599 [DLPN_W])            1.607333
#                           Equity(51600 [WCHN])             30.866333
#                           Equity(51601 [WBAL])             25.000000
#                           Equity(51602 [LDRS])             25.281124
#                           Equity(51603 [STNL_W])                 NaN
#                           Equity(51604 [STNL])                   NaN
#                           Equity(51605 [LACQ_W])                 NaN
#                           Equity(51606 [LACQ])                   NaN
#                           Equity(51607 [SIMS])                   NaN
#                           Equity(51608 [HAIL])                   NaN
#                           Equity(51609 [FITE])                   NaN
#
# [25572 rows x 1 columns]

# %% [markdown]
# Note: factors can also be added to an existing `Pipeline` instance using the `Pipeline.add` method. Using `add` looks something like this:
#     >>> my_pipe = Pipeline()
#     >>> f1 = SomeFactor(...)
#     >>> my_pipe.add(f1, 'f1')

# %% [markdown]
# ###Latest
# The most commonly used built-in `Factor` is `Latest`. The `Latest` factor gets the most recent value of a given data column. This factor is common enough that it is instantiated differently from other factors. The best way to get the latest value of a data column is by getting its `.latest` attribute. As an example, let's update `make_pipeline` to create a latest close price factor and add it to our pipeline:

# %%
def make_pipeline():

    mean_close_20 = SimpleMovingAverage(inputs=[USEquityPricing.close], window_length=20)
    latest_close = USEquityPricing.close.latest

    return Pipeline(
        columns={
            '20_day_mean_close': mean_close_20,
            'latest_close_price': latest_close
        }
    )

# %% [markdown]
# And now, when we make and run our pipeline again, there are two columns in our output dataframe. One column has the 10-day mean close price of each security, and the other has the latest close price.

# %%
result = run_pipeline(make_pipeline(), '2017-12-27', '2017-12-27')
result.head(10)
# Out:
# <b>Pipeline Execution Time:</b> 0.38 Seconds
#                                                20_day_mean_close  \
# 2017-12-27 00:00:00+00:00 Equity(2 [HWM])               25.11000
#                           Equity(21 [AAME])              3.54775
#                           Equity(24 [AAPL])            172.05850
#                           Equity(25 [HWM_PR])           89.99552
#                           Equity(31 [ABAX])             48.44226
#                           Equity(41 [ARCB])             36.78125
#                           Equity(52 [ABM])              41.22795
#                           Equity(53 [ABMD])            191.55400
#                           Equity(62 [ABT])              55.72475
#                           Equity(64 [GOLD])             14.03600
#
#                                                latest_close_price
# 2017-12-27 00:00:00+00:00 Equity(2 [HWM])                   27.07
#                           Equity(21 [AAME])                  3.60
#                           Equity(24 [AAPL])                170.57
#                           Equity(25 [HWM_PR])               91.00
#                           Equity(31 [ABAX])                 49.66
#                           Equity(41 [ARCB])                 36.75
#                           Equity(52 [ABM])                  38.32
#                           Equity(53 [ABMD])                189.64
#                           Equity(62 [ABT])                  56.98
#                           Equity(64 [GOLD])                 14.57

# %% [markdown]
# `.latest` can sometimes return things other than `Factors`. We'll see examples of other possible return types in later lessons.

# %% [markdown]
# ## Default Inputs
# Some factors have default inputs that should never be changed. For example the [VWAP built-in factor](https://www.quantopian.com/help#built-in-factors) is always calculated from `USEquityPricing.close` and `USEquityPricing.volume`. When a factor is always calculated from the same `BoundColumns`, we can call the constructor without specifying `inputs`.

# %%
from quantopian.pipeline.factors import VWAP

def make_pipeline():
    vwap = VWAP(window_length=10)
    
    return Pipeline(columns={'vwap':vwap})

trying = run_pipeline(make_pipeline(), '2017-12-27', '2017-12-27')
trying.head(10)
# Out:
# <b>Pipeline Execution Time:</b> 0.50 Seconds
#                                                      vwap
# 2017-12-27 00:00:00+00:00 Equity(2 [HWM])       25.815757
#                           Equity(21 [AAME])      3.419925
#                           Equity(24 [AAPL])    173.507214
#                           Equity(25 [HWM_PR])   91.405616
#                           Equity(31 [ABAX])     48.416595
#                           Equity(41 [ARCB])     36.339594
#                           Equity(52 [ABM])      38.679049
#                           Equity(53 [ABMD])    191.076510
#                           Equity(62 [ABT])      56.176286
#                           Equity(64 [GOLD])     14.202701

# %% [markdown]
# In the next lesson, we will look at combining factors.
